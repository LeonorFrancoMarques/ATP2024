# %%
import random

print("Jogo: Os 21 fósforos")

print("As regras do jogo são:")
print("Cada jogador (computador ou utilizador) tira 1, 2, 3 ou 4 fósforos, dos 21 iniciais, na sua vez de jogar.")
print("Os jogadores jogam alternadamente e perde quem tirar o último fósforo!")

print("Existem duas modalidades neste jogo:")
print("Modalidade 1 - o utilizador joga em primeiro lugar e o computador começa a jogar em segundo lugar.")
print("Modalidade 2 - o computador joga em primeiro lugar e o utilizador começa a jogar em segundo lugar.")

mod = int(input("Qual a modalidade que quer jogar? 1 ou 2?"))
inicio = 21

while mod != 1 and mod != 2:
    print("Resposta inválida.")
    mod = int(input("Qual a modalidade que quer jogar? 1 ou 2?"))

if mod == 1:
    print("Você é o primeiro a jogar!")
    numfosforos = int(input("Quantos fósforos, dos 21 iniciais, quer tirar? 1, 2, 3 ou 4?"))
    while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
        print("Resposta inválida.")
        numfosforos = int(input("Quantos fósforos, dos 21 iniciais, quer tirar? 1, 2, 3 ou 4?"))
    if numfosforos == 1 or numfosforos == 2 or numfosforos == 3 or numfosforos == 4:
        inicio = inicio - numfosforos
        while inicio > 5:
            fosforos_pc = 5 - numfosforos
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos. Quantos quer tirar?")
            numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
                print("Resposta inválida.")
                numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
                inicio = inicio - numfosforos
        if inicio <= 5:
            fosforos_pc = inicio - 1
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            print("Você perdeu o jogo!")

if mod == 2:
    print("O computador é o primeiro a jogar!")
    fosforos_pc = random.randint(1,4)
    inicio = inicio - fosforos_pc
    print("O computador tirou {fosforos_pc} e sobra(m) {inicio} fósforos.")
    numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
    while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
        print("Resposta inválida.")
        numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
    if numfosforos == 1 or numfosforos == 2 or numfosforos == 3 or numfosforos == 4:
        inicio = inicio - numfosforos
        if inicio<21 and inicio>=17:
            fosforos_pc = inicio - 16
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
                print("Resposta inválida.")
                numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            inicio = inicio - numfosforos
        elif inicio == 16:
            fosforos_pc = random.randint(1,4)
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
                print("Resposta inválida.")
                numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
                inicio = inicio - numfosforos
        if inicio <= 15 and inicio >= 12:
            fosforos_pc = inicio - 11
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
                print("Resposta inválida.")
                numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
                inicio = inicio - numfosforos
        elif inicio == 11:
            fosforos_pc = random.randint(1,4)
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
                print("Resposta inválida.")
                numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
                inicio = inicio - numfosforos
        if inicio <= 10 and inicio >= 7:
            fosforos_pc = inicio - 6
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
                print("Resposta inválida.")
                numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
                inicio = inicio - numfosforos
        elif inicio == 6:
            fosforos_pc = random.randint(1,4)
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
            while numfosforos != 1 and numfosforos != 2 and numfosforos != 3 and numfosforos != 4:
                print("Resposta inválida.")
                numfosforos = int(input(f"Dos {inicio} fósforos, quantos quer tirar? 1, 2, 3 ou 4?"))
                inicio = inicio - numfosforos
        if inicio <= 5 and inicio >= 2:
            fosforos_pc = inicio - 1
            inicio = inicio - fosforos_pc
            print(f"O computador tirou {fosforos_pc} e sobram {inicio} fósforos.")
            if inicio == 1:
                print("Você perdeu o jogo!")
        else:
            print("O computador perdeu o jogo!")
# Out:
# Jogo: Os 21 fósforos
# As regras do jogo são:
# Cada jogador (computador ou utilizador) tira 1, 2, 3 ou 4 fósforos, dos 21 iniciais, na sua vez de jogar.
# Os jogadores jogam alternadamente e perde quem tirar o último fósforo!
# Existem duas modalidades neste jogo:
# Modalidade 1 - o utilizador joga em primeiro lugar e o computador começa a jogar em segundo lugar.
# Modalidade 2 - o computador joga em primeiro lugar e o utilizador começa a jogar em segundo lugar.
# Você é o primeiro a jogar!
# O computador tirou 4 e sobram 16 fósforos. Quantos quer tirar?
# O computador tirou 1 e sobram 15 fósforos. Quantos quer tirar?
# O computador tirou 3 e sobram 12 fósforos. Quantos quer tirar?
# O computador tirou 2 e sobram 10 fósforos. Quantos quer tirar?
# O computador tirou 4 e sobram 6 fósforos. Quantos quer tirar?
# O computador tirou 3 e sobram 3 fósforos. Quantos quer tirar?
# O computador tirou 2 e sobram 1 fósforos.
# Você perdeu o jogo!
